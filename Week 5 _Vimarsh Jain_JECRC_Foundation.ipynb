# %% [markdown]
# # 📘 Deep Learning Text Generation Learning Project
# ## Text Generation using **Vanilla RNN, LSTM, and GRU**
#
# This notebook is built for **students and beginners** to understand how sequence models learn:
# - grammar
# - sentence flow
# - contextual dependencies
# - next-word prediction
# - text generation
#
# 🎯 **Goal:** Compare **Simple RNN vs LSTM vs GRU** on the same text corpus and understand why gated architectures perform better.

# %% [markdown]
# # 🧠 Problem Statement
# Design and implement a DL model capable of learning the underlying structure, grammar, and contextual dependencies of a given text corpus to generate coherent and meaningful text sequences using:
#
# 1. **Vanilla RNN**
# 2. **LSTM**
# 3. **GRU**
#
# Then compare:
# - training loss
# - generated text quality
# - memory handling
# - long-term dependency learning

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
import numpy as np
import matplotlib.pyplot as plt
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 📥 Load Text Corpus
# We use a **small built-in sample corpus** so students can run this quickly.
# You can later replace it with:
# - Shakespeare text
# - song lyrics
# - chatbot data
# - story paragraphs
# - custom PDF extracted text

# %%
corpus = '''
deep learning is transforming artificial intelligence
recurrent neural networks are useful for sequential data
lstm helps remember long term dependencies
gru is faster and simpler than lstm
text generation models predict the next word
deep learning models can generate meaningful sentences
'''
print(corpus)
# Out:
# deep learning is transforming artificial intelligence
# recurrent neural networks are useful for sequential data
# lstm helps remember long term dependencies
# gru is faster and simpler than lstm
# text generation models predict the next word
# deep learning models can generate meaningful sentences

# %% [markdown]
# # 🔤 Tokenization & Sequence Creation
# We convert text into integer tokens and create **n-gram style sequences**
# for next-word prediction.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([corpus])

total_words = len(tokenizer.word_index) + 1
print("Vocabulary size:", total_words)

input_sequences = []
for line in corpus.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_seq = token_list[:i+1]
        input_sequences.append(n_gram_seq)

max_len = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# Vocabulary size: 37
# X shape: (35, 7)
# y shape: (35,)

# %% [markdown]
# # 🧠 Model 1: Vanilla RNN
# This is the baseline sequential model.
# It struggles with long-term dependencies because of vanishing gradients.

# %%
rnn_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    SimpleRNN(64),
    Dense(total_words, activation='softmax')
])

rnn_model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

rnn_history = rnn_model.fit(X, y, epochs=100, verbose=0)
print("Vanilla RNN training completed")
# Out:
# Vanilla RNN training completed

# %% [markdown]
# # 🔒 Model 2: LSTM
# LSTM uses **input, forget, and output gates**
# to preserve long-term memory.

# %%
lstm_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    LSTM(64),
    Dense(total_words, activation='softmax')
])

lstm_model.compile(loss='sparse_categorical_crossentropy',
                   optimizer='adam',
                   metrics=['accuracy'])

lstm_history = lstm_model.fit(X, y, epochs=100, verbose=0)
print("LSTM training completed")
# Out:
# LSTM training completed

# %% [markdown]
# # ⚡ Model 3: GRU
# GRU uses **reset + update gates**.
# It is computationally faster than LSTM and often gives similar results.

# %%
gru_model = Sequential([
    Embedding(total_words, 32, input_length=max_len-1),
    GRU(64),
    Dense(total_words, activation='softmax')
])

gru_model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

gru_history = gru_model.fit(X, y, epochs=100, verbose=0)
print("GRU training completed")
# Out:
# GRU training completed

# %% [markdown]
# ## 📉 Compare Training Loss

# %%
plt.figure(figsize=(10,4))
plt.plot(rnn_history.history['loss'], label='RNN')
plt.plot(lstm_history.history['loss'], label='LSTM')
plt.plot(gru_history.history['loss'], label='GRU')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss Comparison")
plt.legend()
plt.show()

# %% [markdown]
# # ✍️ Text Generation Function
# This function predicts the next word repeatedly to generate a sentence.

# %%
def generate_text(model, seed_text, next_words=5):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)[0]

        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# %% [markdown]
# ## 🧪 Generate Text Samples

# %%
  print("RNN :", generate_text(rnn_model, "deep learning", 5))
  print("LSTM:", generate_text(lstm_model, "deep learning", 5))
  print("GRU :", generate_text(gru_model, "deep learning", 5))
# Out:
# RNN : deep learning models can generate meaningful sentences
# LSTM: deep learning learning models predict meaningful sentences
# GRU : deep learning is transforming artificial intelligence intelligence

# %% [markdown]
# # 📚 Student Learning Tasks
# ### ✅ Beginner Tasks
# 1. Replace corpus with your own paragraph
# 2. Increase embedding dimension
# 3. Increase epochs to 200
# 4. Change hidden units 64 → 128
# 5. Generate 10 words instead of 5

# %% [markdown]
# # ✅ Conclusion
# - **Vanilla RNN** learns short patterns but struggles with memory
# - **LSTM** captures long-range grammar dependencies better
# - **GRU** gives similar performance with fewer gates and faster training
# - This notebook helps students understand **sequence modeling mathematically and practically**

# %% [markdown]
# # Task 1 — Custom Corpus

# %%
corpus = '''
the night sky has fascinated humans for thousands of years
stars planets and galaxies fill the vast dark universe
space exploration helps us understand our place in the cosmos
astronauts travel beyond earth to explore distant worlds
rockets carry satellites and crews into orbit around the planet
the moon was the first major destination for human explorers
mars is now the next frontier for scientific discovery
telescopes allow scientists to observe galaxies far away
artificial intelligence is helping scientists analyze space data faster
deep learning models can predict patterns in astronomical images
the future of space travel depends on continued human curiosity
exploring space teaches us patience persistence and the value of teamwork
'''

print(corpus)
# Out:
# the night sky has fascinated humans for thousands of years
# stars planets and galaxies fill the vast dark universe
# space exploration helps us understand our place in the cosmos
# astronauts travel beyond earth to explore distant worlds
# rockets carry satellites and crews into orbit around the planet
# the moon was the first major destination for human explorers
# mars is now the next frontier for scientific discovery
# telescopes allow scientists to observe galaxies far away
# artificial intelligence is helping scientists analyze space data faster
# deep learning models can predict patterns in astronomical images
# the future of space travel depends on continued human curiosity
# exploring space teaches us patience persistence and the value of teamwork

# %% [markdown]
# # Re-running Tokenization & Sequence Creation

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([corpus])
total_words = len(tokenizer.word_index) + 1
print("Vocabulary size:", total_words, "(was 37 in the baseline)")

input_sequences = []
for line in corpus.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        input_sequences.append(token_list[:i+1])

max_len = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

X = input_sequences[:, :-1]
y = input_sequences[:, -1]

print("Total training pairs:", len(input_sequences), "(was 35 in the baseline)")
print("X shape:", X.shape)
print("y shape:", y.shape)
print("max_len (incl. label):", max_len, "(was 8 in the baseline)")
# Out:
# Vocabulary size: 89 (was 37 in the baseline)
# Total training pairs: 101 (was 35 in the baseline)
# X shape: (101, 10)
# y shape: (101,)
# max_len (incl. label): 11 (was 8 in the baseline)

# %% [markdown]
#  # Tasks 2,3 & 4 — Scale Up Embedding Dimension and Hidden Units & Epoch to 200

# %%
EMBED_DIM = 100
HIDDEN_UNITS = 128


rnn_model_2 = Sequential([
    Embedding(total_words, 100, input_length=max_len-1),
    SimpleRNN(128),
    Dense(total_words, activation='softmax')
])

rnn_model_2.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

rnn_history = rnn_model_2.fit(X, y, epochs=200, verbose=0)
print("Vanilla RNN training-2 completed")


lstm_model_2 = Sequential([
    Embedding(total_words, 100, input_length=max_len-1),
    LSTM(128),
    Dense(total_words, activation='softmax')
])

lstm_model_2.compile(loss='sparse_categorical_crossentropy',
                   optimizer='adam',
                   metrics=['accuracy'])

lstm_history = lstm_model_2.fit(X, y, epochs=200, verbose=0)
print("LSTM training-2 completed")

gru_model_2 = Sequential([
    Embedding(total_words, 100, input_length=max_len-1),
    GRU(128),
    Dense(total_words, activation='softmax')
])

gru_model_2.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

gru_history = gru_model_2.fit(X, y, epochs=200, verbose=0)
print("GRU training-2 completed")
# Out:
# Vanilla RNN training-2 completed
# LSTM training-2 completed
# GRU training-2 completed

# %% [markdown]
# # Task 5 — Generate 10 Words Instead of 5

# %%
def generate_text(model, seed_text, next_words=5):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)[0]

        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text



print("RNN :", generate_text(rnn_model_2, "deep learning", 10))
print("LSTM:", generate_text(lstm_model_2, "deep learning", 10))
print("GRU :", generate_text(gru_model_2, "deep learning", 10))
# Out:
# RNN : deep learning models can predict patterns in astronomical images data faster cosmos
# LSTM: deep learning models can predict patterns in astronomical images images images explorers
# GRU : deep learning models can predict patterns in astronomical images images images images
